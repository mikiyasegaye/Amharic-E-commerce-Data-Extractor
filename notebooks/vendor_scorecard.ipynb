# %%
import pandas as pd
import numpy as np
from datetime import datetime

df = pd.read_csv("../data/raw/telegram_data.csv")

ner_df = pd.read_csv("../data/processed/telegram_data_cleaned.csv")

df = df.merge(ner_df, on="post_id", how="left")

df["timestamp"] = pd.to_datetime(df["timestamp"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9c/z436vv391wd5csdhpxszxk600000gn/T/ipykernel_83237/3710533015.py in ?()
#       5 df = pd.read_csv("../data/raw/telegram_data.csv")
#       6
#       7 ner_df = pd.read_csv("../data/processed/telegram_data_cleaned.csv")
#       8
# ----> 9 df = df.merge(ner_df, on="post_id", how="left")
#      10
#      11 df["timestamp"] = pd.to_datetime(df["timestamp"])
#
# ~/MK_Lab/10 Academy/Amharic-E-commerce-Data-Extractor/venv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10835         validate: MergeValidate | None = None,
#   10836     ) -> DataFrame:
#   10837         from pandas.core.reshape.merge import merge
#   10838
# > 10839         return merge(
#   10840             self,
# ...
